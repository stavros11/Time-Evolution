# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import matplotlib
matplotlib.rcParams['mathtext.fontset'] = 'cm'
matplotlib.rcParams['font.family'] = 'STIXGeneral'
matplotlib.rcParams["font.size"] = 26

# %%
machine_type = "fullwv"
n_sites = 4
time_steps = 20
n_samples

all_states = h5py.File("allstates_{}_N{}M{}.h5py".format(machine_type, n_sites, time_steps), "r")
sampling = h5py.File("sampling_{}_N{}M{}.h5py".format(machine_type, n_sites, time_steps), "r")

# %%
plt.figure(figsize=(20, 5))
plt.suptitle("Full Wavefunction, $N={}$, $T={}$, $N_s={}$k".format(n_sites, time_steps, 20))

plt.subplot(121)
plt.semilogy(sampling["sampled_Eloc"][:].real, label="MC (sampled)", color="orange")
plt.semilogy(sampling["exact_Eloc"][:].real, label="MC (exact)", color="red", linewidth=2.0)
plt.semilogy(all_states["exact_Eloc"][:].real, label="Exact", color="blue", linewidth=2.4)
plt.xlabel("Epochs")
plt.ylabel("$E_\mathrm{loc}$")
plt.legend()

plt.subplot(122)
plt.semilogy(1 - all_states["overlaps"][:], label="Exact", linewidth=2.5, color="blue")
plt.semilogy(1 - sampling["overlaps"][:], label="MC", linewidth=2.5, color="red")
plt.xlabel("Epochs")
plt.ylabel("Overlaps")
plt.legend()
plt.show()

# %%
all_states.close()
sampling.close()
